# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488490 sha256=7dfd51d05b4ce62cf676d81cf6d5b19035e64c1a621e5c5cc1e5b2b4726561d3
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
# import library for pyspark
import pyspark

# %%
# To create SparkContext
from pyspark import SparkContext

# %%
sc = SparkContext()

# %%
text_file = sc.textFile("sample.txt")

# %%
text_file.collect()

# %%
new1 = text_file.flatMap(lambda line: line.split("@"))

# %%
new1.collect()

# %%
text_file = sc.textFile("sample.txt")

# %%
counts = text_file.flatMap(lambda line: line.split(" "))

# %%
counts.collect()

# %%
counts1 = counts.map(lambda word: (word, 1))

# %%
counts1.collect()

# %%
counts3 = counts1.reduceByKey(lambda x, y: x + y)

# %%
counts3.collect()

# %%
counts3.filter(lambda x: x[0] not in ["for", "and", "not", "on", "the", "as", "of", "is"]).collect()
